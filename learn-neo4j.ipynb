# %%
import pandas as pd
entities = pd.read_parquet('./ragtest/output/20240730-094138/artifacts/create_final_entities.parquet')
relationships = pd.read_parquet('./ragtest/output/20240730-094138/artifacts/create_final_relationships.parquet')
text_units = pd.read_parquet('./ragtest/output/20240730-094138/artifacts/create_final_text_units.parquet')
communities = pd.read_parquet('./ragtest/output/20240730-094138/artifacts/create_final_communities.parquet')
community_reports = pd.read_parquet('./ragtest/output/20240730-094138/artifacts/create_final_community_reports.parquet')

# %%
text_units.head(5)
# Out:
#                                  id  \
# 0  8f50b6eeae866a5ad1a48a2709c38436
# 1  1046bacc8c5c0a98aa881fd2ba0d2565
# 2  dacfeaa720e321850493ea5f4cf3ac4d
#
#                                                 text  n_tokens  \
# 0  ﻿昭和30年代前半の初夏 (5月) 。小学生のサツキと、幼い妹のメイ、父の三人が、入院中の母...      1200
# 1  許しを得てメイを教室に入れてもらい残りの2限をやり過ごす事になる。\nそして放課後の帰り道。...      1200
# 2  泣きしてしまう。しっかり者のサツキも、内心は「もしかしたら母を失うかもしれない」という不安と...       761
#
#                          document_ids  \
# 0  [3bf676676e28f0daf193de77ba2492a0]
# 1  [3bf676676e28f0daf193de77ba2492a0]
# 2  [3bf676676e28f0daf193de77ba2492a0]
#
#                                           entity_ids  \
# 0  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 1  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 2  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
#
#                                     relationship_ids
# 0                 [3b040bcc19f14e04880ae52881a89c1c]
# 1  [3d6b216c14354332b1bf1927ba168986, 1c109cfdc37...
# ...

# %%
entities.head(20)
# Out:
#                                   id        name      type  \
# 0   b45241d70f0e43fca764df95b2b81f77       "サツキ"  "PERSON"
# 1   4119fd06010c494caa07f439b333f4c5        "メイ"  "PERSON"
# 2   d3835bf3dda84ead99deadbeac5d0d7d         "父"  "PERSON"
# 3   077d2820ae1845bcbb1803379a3d1eae         "母"  "PERSON"
# 4   3671ea0dd4e84c1a9b02c5ab2c8f4bac  "隣のおばあちゃん"  "PERSON"
# 5   19a7f254a5d64566ab5cc15472df02de       "カンタ"  "PERSON"
# 6   e7ffaee9d31d4d3c96e04f911d0a8f9e       "トトロ"     "GEO"
# 7   f7e11b0e297a44a896dc67928368f600  "("ENTITY"
# 8   1fd3fa8bb5a2408790042ab9573779ee     "ススワタリ"     "GEO"
# 9   27f9fbe6ad8c4a8b9acee0d3596ed57c        "塚森"     "GEO"
# 10  e1fd0e904a53409aada44442f23a51cb      "ネコバス"     "GEO"
# 11  de988724cfdf45cebfba3b13c43ceede       "バス停"     "GEO"
# 12  96aad7cb4b7d40e9b7e13b94a67af206        "病院"     "GEO"
# 13  c9632a35146940c2a86167c7726d35e9        "学校"     "GEO"
# 14  9646481f66ce4fd2b08c2eddda42fc82       "田んぼ"     "GEO"
# ...

# %%
relationships.head(5)
# Out:
#   source      target  weight  \
# 0  "サツキ"  "("ENTITY"     1.0
# 1  "サツキ"        "メイ"   123.0
# 2  "サツキ"       "カンタ"     7.0
# 3  "サツキ"       "トトロ"     3.0
# 4  "サツキ"      "大トトロ"     2.0
#
#                                          description  \
# 0                                               "名前"
# 1  "\u30b5\u30c4\u30ad"と"\u30e1\u30a4"は、互いに密接に関連し...
# 2                   "サツキとカンタは友達で、カンタはサツキとメイに親切にします。"
# 3  "\u30b5\u30c4\u30ad"は"\u30c8\u30c8\u30ed"と密接に関...
# 4              "サツキは大トトロと出会い、大トトロの助けを借りてメイと共に成長します。"
#
#                                        text_unit_ids  \
# 0                 [8f50b6eeae866a5ad1a48a2709c38436]
# 1  [1046bacc8c5c0a98aa881fd2ba0d2565, dacfeaa720e...
# 2                 [1046bacc8c5c0a98aa881fd2ba0d2565]
# 3  [1046bacc8c5c0a98aa881fd2ba0d2565, dacfeaa720e...
# 4                 [1046bacc8c5c0a98aa881fd2ba0d2565]
#
#                                  id human_readable_id  source_degree  \
# ...

# %%
communities.head(5)
# Out:
#   id        title  level raw_community  \
# 0  0  Community 0      0             0
# 1  1  Community 1      0             1
#
#                                     relationship_ids  \
# 0  [3b040bcc19f14e04880ae52881a89c1c, 3d6b216c143...
# 1  [3ce7c210a21b4deebad7cc9308148d86, 3d0dcbc8971...
#
#                                        text_unit_ids
# 0  [1046bacc8c5c0a98aa881fd2ba0d2565,8f50b6eeae86...
# 1  [1046bacc8c5c0a98aa881fd2ba0d2565,8f50b6eeae86...

# %%
community_reports.head(5)
# Out:
#   community                                       full_content  level  rank  \
# 0         0  # サツキとメイ、トトロたち、ネコバス、大トトロ、カンタに関するレポート\n\nこのコミュニ...      0   8.0
# 1         1  # トトロとネコバスのコミュニティレポート\n\nこのコミュニティは、トトロとネコバスを中心...      0   8.0
#
#                                 title  \
# 0  サツキとメイ、トトロたち、ネコバス、大トトロ、カンタに関するレポート
# 1                 トトロとネコバスのコミュニティレポート
#
#                                     rank_explanation  \
# 0  このコミュニティは、エンティティ間の協力関係や相互依存性が高く、潜在的な影響力が大きいため、...
# 1  このコミュニティは、トトロとネコバスの影響力により、ユーザーに強い感情的なつながりを提供し、...
#
#                                              summary  \
# 0  このコミュニティは、サツキとメイを中心に、トトロたち、ネコバス、大トトロ、カンタといったエン...
# 1  このコミュニティは、トトロとネコバスを中心に構成されており、サツキとメイが重要な役割を果たし...
#
#                                             findings  \
# 0  [{'explanation': 'サツキとメイは、トトロたちや大トトロ、ネコバス、カンタと...
# 1  [{'explanation': 'トトロはネコバスを呼び寄せ、サツキとメイを冒険に連れ出す...
#
#                                    full_content_json  \
# 0  {\n    "title": "\u30b5\u30c4\u30ad\u3068\u30e...
# ...

# %%
import pandas as pd
from neo4j import GraphDatabase
import time

# %%
NEO4J_URI = "neo4j://localhost"
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "neo4jneo4j" 
NEO4J_DATABASE = "neo4j"
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
def import_data(cypher, df, batch_size=1000):

    for i in range(0,len(df), batch_size):
        batch = df.iloc[i: min(i+batch_size, len(df))]
        result = driver.execute_query("UNWIND $rows AS value " + cypher, 
                                      rows=batch.to_dict('records'),
                                      database_=NEO4J_DATABASE)
        print(result.summary.counters)
    return

# %%
#导入text units
cypher_text_units = """
MERGE (c:__Chunk__ {id:value.id})
SET c += value {.text, .n_tokens}
WITH c, value
UNWIND value.document_ids AS document
MATCH (d:__Document__ {id:document})
MERGE (c)-[:PART_OF]->(d)
"""

import_data(cypher_text_units, text_units)
# Out:
# {'_contains_updates': True, 'labels_added': 3, 'nodes_created': 3, 'properties_set': 9}

# %%
#加载entities
cypher_entities= """
MERGE (e:__Entity__ {id:value.id})
SET e += value {.human_readable_id, .description, name:replace(value.name,'"','')}
WITH e, value
CALL db.create.setNodeVectorProperty(e, "description_embedding", value.description_embedding)
CALL apoc.create.addLabels(e, case when coalesce(value.type,"") = "" then [] else [apoc.text.upperCamelCase(replace(value.type,'"',''))] end) yield node
UNWIND value.text_unit_ids AS text_unit
MATCH (c:__Chunk__ {id:text_unit})
MERGE (c)-[:HAS_ENTITY]->(e)
"""

import_data(cypher_entities, entities)
# Out:
# {'_contains_updates': True, 'labels_added': 27, 'relationships_created': 41, 'nodes_created': 27, 'properties_set': 108}

# %%
#导入relationships
cypher_relationships = """
    MATCH (source:__Entity__ {name:replace(value.source,'"','')})
    MATCH (target:__Entity__ {name:replace(value.target,'"','')})
    // not necessary to merge on id as there is only one relationship per pair
    MERGE (source)-[rel:RELATED {id: value.id}]->(target)
    SET rel += value {.rank, .weight, .human_readable_id, .description, .text_unit_ids}
    RETURN count(*) as createdRels
"""

import_data(cypher_relationships, relationships)
# Out:
# {'_contains_updates': True, 'relationships_created': 14, 'properties_set': 84}

# %%
#导入communities
cypher_communities = """
MERGE (c:__Community__ {community:value.id})
SET c += value {.level, .title}
/*
UNWIND value.text_unit_ids as text_unit_id
MATCH (t:__Chunk__ {id:text_unit_id})
MERGE (c)-[:HAS_CHUNK]->(t)
WITH distinct c, value
*/
WITH *
UNWIND value.relationship_ids as rel_id
MATCH (start:__Entity__)-[:RELATED {id:rel_id}]->(end:__Entity__)
MERGE (start)-[:IN_COMMUNITY]->(c)
MERGE (end)-[:IN_COMMUNITY]->(c)
RETURn count(distinct c) as createdCommunities
"""

import_data(cypher_communities, communities)
# Out:
# {'_contains_updates': True, 'labels_added': 2, 'relationships_created': 12, 'nodes_created': 2, 'properties_set': 6}

# %%
#导入community_reports
cypher_community_reports = """MATCH (c:__Community__ {community: value.community})
SET c += value {.level, .title, .rank, .rank_explanation, .full_content, .summary}
WITH c, value
UNWIND range(0, size(value.findings)-1) AS finding_idx
WITH c, value, finding_idx, value.findings[finding_idx] as finding
MERGE (c)-[:HAS_FINDING]->(f:Finding {id: finding_idx})
SET f += finding"""
import_data(cypher_community_reports, community_reports)
# Out:
# {'_contains_updates': True, 'labels_added': 10, 'relationships_created': 10, 'nodes_created': 10, 'properties_set': 42}
