# %%
import pandas as pd
base_text_units = pd.read_parquet('./data/output/prod/artifacts/create_base_text_units.parquet')
base_text_units
# Out:
#                                  id  \
# 0  dfdbec60270577f4607207259ab30185
# 1  eae8cf7388dd8dbd3050241c2220a0e1
# 2  5067adf50207598e357e88232eda3599
# 3  a0678cdfe9941d8478a1791feac93541
# 4  4b0b028654c036005f1af49d8be35b39
#
#                                                chunk  \
# 0  白话版《水浒传》·武松景阳冈打虎\n武松一路走了好几天，到了阳谷县的地界。中午的时候，他觉得...
# 1  右三个时辰内结伴过冈。”武松笑道：“这一定是那店家用来唬人的把戏，目的就是为了让别人到他的店...
# 2  �老虎的嘴一直按到那土坑里，只顾猛打。\n\n打到六七十拳的时候，老虎的眼里、口里、鼻子里、...
# 3  莲的企图。就这么住到了十一月，一天，天上下起大雪。潘金莲一早就把武大郎赶出去卖炊饼，还买了些...
# 4  是个老实人，我不在的时候，怕你受别人欺负。这段时间里，大哥就少做些买卖，不要和人去喝酒，早点...
#
#                            chunk_id                        document_ids  \
# 0  dfdbec60270577f4607207259ab30185  [0060df896c3a34f5a9489ee2405bd5a5]
# 1  eae8cf7388dd8dbd3050241c2220a0e1  [0060df896c3a34f5a9489ee2405bd5a5]
# 2  5067adf50207598e357e88232eda3599  [0060df896c3a34f5a9489ee2405bd5a5]
# 3  a0678cdfe9941d8478a1791feac93541  [0060df896c3a34f5a9489ee2405bd5a5]
# 4  4b0b028654c036005f1af49d8be35b39  [0060df896c3a34f5a9489ee2405bd5a5]
#
#    n_tokens
# 0      1200
# 1      1200
# 2      1200
# 3      1200
# 4       198

# %%
base_extracted_entities = pd.read_parquet('./data/output/prod/artifacts/create_base_extracted_entities.parquet')
base_extracted_entities
# Out:
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...

# %%
final_covariates = pd.read_parquet('./data/output/prod/artifacts/create_final_covariates.parquet')
final_covariates
# Out:
#                                       id human_readable_id covariate_type  \
# 0   bf0f523c-0791-4664-abd5-3ae7e6f09428                 1          claim
# 1   211bb47c-6799-4160-911e-90873aec1d0e                 2          claim
# 2   16d3776b-3b23-4d7c-9a42-cf084921edf1                 3          claim
# 3   71060451-d5ef-4973-96f3-7ef0d3f66449                 4          claim
# 4   a1dde430-8e35-4e61-9fad-dd146fafb7b8                 5          claim
# 5   ad91e30f-4a1c-4e50-8d53-35740c066716                 6          claim
# 6   2937b670-02bd-4faa-a222-e49a4747e3ee                 7          claim
# 7   b2735a62-0721-4d45-9410-6778bfeddb25                 8          claim
# 8   8c503fc1-c3b3-4539-a6a0-369ae3bb6d23                 9          claim
# 9   95ac405a-230d-4b70-80a5-94bf5a7446c7                10          claim
# 10  446f41bd-0e52-482e-a9b7-ba462d96c5a6                11          claim
# 11  d31b02c4-6dea-47fc-9d40-32495707fe69                12          claim
# 12  e487ac1d-1531-4387-8531-fa711470aa8f                13          claim
# 13  170b0a41-681f-448d-a531-57bb34e08e74                14          claim
# 14  18c749a3-56f4-4ea2-8628-31cafe420258                15          claim
#
#     type                                        description  \
# 0     旅行                              武松从阳谷县出发，在路上的酒店里喝酒吃肉。
# 1     酒精                     酒店的小二警告武松不要再喝更多的酒，并解释了酒店的酒很强劲。
# 2     危险                   酒店的小二警告武松，前面的景阳冈上有只老虎，建议他留在酒店过夜。
# 3     危险                        武松认为酒店关于老虎的警告是虚张声势，并继续他的旅程。
# 4     危险                         武松怀疑前面的景阳冈上可能有老虎，但仍决定继续前进。
# 5     怀疑                      武松怀疑酒店关于老虎的警告是虚张声势，目的是吸引客人投宿。
# 6     怀疑                         武松认为酒店关于老虎的警告不是虚张声势，而是真实的。
# 7     勇武  武松不怕传言,独自穿过冈子,并在山神庙发现了告示。他没有退缩,而是继续前进,甚至在遇到老虎时...
# 8     危险                                  老虎袭击武松,但被武松闪躲并反击。
# 9     力量                                武松用拳头和棍子打老虎,最终杀死了它。
# 10  None                                               None
# 11    调情                           潘金莲向武松调情, 试图勾引他, 但被武松拒绝。
# 12    诬陷                       潘金莲在武大郎面前诬陷武松调戏她,导致武松搬出武大郎家。
# 13    保护               武松担心武大郎受人欺负,嘱咐武大郎照顾好自己,不要和别人喝酒,早点回家。
# 14  None                                               None
#
#                                            subject_id subject_type object_id  \
# 0                                                  武松         None      NONE
# 1                                                  酒店         None        武松
# 2                                                  酒店         None        武松
# 3                                                  酒店         None        武松
# 4                                                  武松         None      NONE
# 5                                                  武松         None        酒店
# 6                                                  酒店         None        武松
# 7                                                  武松         None      NONE
# 8                                                  老虎         None        武松
# 9                                                  武松         None        老虎
# 10  申し訳ありません、入力されたテキストに含まれるエンティティや関連するステートメントが見つかり...         None      None
# 11                                                潘金莲         None        武松
# 12                                                潘金莲         None        武松
# 13                                                 武松         None       武大郎
# 14                                                            None      None
#
#    object_type     status start_date end_date  \
# 0         None       TRUE       NONE     NONE
# 1         None       TRUE       NONE     NONE
# 2         None       TRUE       NONE     NONE
# 3         None      FALSE       NONE     NONE
# 4         None  SUSPECTED       NONE     NONE
# 5         None       TRUE       NONE     NONE
# 6         None      FALSE       NONE     NONE
# 7         None       TRUE       NONE     NONE
# 8         None       TRUE       NONE     NONE
# 9         None       TRUE       NONE     NONE
# 10        None       None       None     None
# 11        None       TRUE       NONE     NONE
# 12        None       TRUE       NONE     NONE
# 13        None       TRUE       NONE     NONE
# 14        None       None       None     None
#
#                                           source_text  \
# 0                                 武松一路走了好几天，到了阳谷县的地界。
# 1      酒店门前的招旗上写着“三碗不过冈”。武松一连喝了十五碗酒，小二警告他不要再喝了，说酒很劲道。
# 2                小二追上武松，警告他前面有只老虎，建议他留在酒店过夜，等其他人一起过冈。
# 3          武松并不理会关于老虎的警告，认为那是酒店用来吓唬人的把戏，目的是让别人到酒店里投宿。
# 4                            武松只管走到景阳冈上来，不理会酒店和小二的警告。
# 5                         武松认为酒店关于老虎的警告是为了吸引客人到酒店里投宿。
# 6                              武松笑道:“这一定是那店家用来唬人的把戏。”
# 7   武松只管走到冈子上来，这时候太阳已经开始下山了。他走了不到半里路，就看到一个破败的山神庙。庙...
# 8   那老虎又渴又饿，将两只爪子往地上按一按，整个身子向上一跃，朝武松扑了过来。武松见老虎扑来，就...
# 9   武松双手抡起哨棒,用尽全力打老虎,但没打中。老虎转身扑向武松,武松跳起来,一把揪住老虎的毛,...
# 10                                               None
# 11  潘金莲一早就把武大郎赶出去卖炊饼，还买了些酒肉，烧了一盆炭火放到武松房里，心想：“我今天就来...
# 12  潘金莲说：“我见他冒雪回家，赶紧端来酒菜给他吃，他见家里没人，竟然说些话来调戏我！”武大郎说...
# 13  武松对哥嫂说：“知县大人派我去东京办事，要两三个月。我知道大哥是个老实人，我不在的时候，怕你...
# 14                                               None
#
#                         text_unit_id                        document_ids  \
# 0   dfdbec60270577f4607207259ab30185  [0060df896c3a34f5a9489ee2405bd5a5]
# 1   dfdbec60270577f4607207259ab30185  [0060df896c3a34f5a9489ee2405bd5a5]
# 2   dfdbec60270577f4607207259ab30185  [0060df896c3a34f5a9489ee2405bd5a5]
# 3   dfdbec60270577f4607207259ab30185  [0060df896c3a34f5a9489ee2405bd5a5]
# 4   dfdbec60270577f4607207259ab30185  [0060df896c3a34f5a9489ee2405bd5a5]
# 5   dfdbec60270577f4607207259ab30185  [0060df896c3a34f5a9489ee2405bd5a5]
# 6   dfdbec60270577f4607207259ab30185  [0060df896c3a34f5a9489ee2405bd5a5]
# 7   eae8cf7388dd8dbd3050241c2220a0e1  [0060df896c3a34f5a9489ee2405bd5a5]
# 8   eae8cf7388dd8dbd3050241c2220a0e1  [0060df896c3a34f5a9489ee2405bd5a5]
# 9   eae8cf7388dd8dbd3050241c2220a0e1  [0060df896c3a34f5a9489ee2405bd5a5]
# 10  5067adf50207598e357e88232eda3599  [0060df896c3a34f5a9489ee2405bd5a5]
# 11  a0678cdfe9941d8478a1791feac93541  [0060df896c3a34f5a9489ee2405bd5a5]
# 12  a0678cdfe9941d8478a1791feac93541  [0060df896c3a34f5a9489ee2405bd5a5]
# 13  a0678cdfe9941d8478a1791feac93541  [0060df896c3a34f5a9489ee2405bd5a5]
# 14  4b0b028654c036005f1af49d8be35b39  [0060df896c3a34f5a9489ee2405bd5a5]
#
#     n_tokens
# 0       1200
# 1       1200
# 2       1200
# 3       1200
# 4       1200
# 5       1200
# 6       1200
# 7       1200
# 8       1200
# 9       1200
# 10      1200
# 11      1200
# 12      1200
# 13      1200
# 14       198

# %%
join_text_units_to_covariate_ids = pd.read_parquet('./data/output/prod/artifacts/join_text_units_to_covariate_ids.parquet')
join_text_units_to_covariate_ids
# Out:
#                        text_unit_id  \
# 0  dfdbec60270577f4607207259ab30185
# 1  eae8cf7388dd8dbd3050241c2220a0e1
# 2  5067adf50207598e357e88232eda3599
# 3  a0678cdfe9941d8478a1791feac93541
# 4  4b0b028654c036005f1af49d8be35b39
#
#                                        covariate_ids  \
# 0  [bf0f523c-0791-4664-abd5-3ae7e6f09428, 211bb47...
# 1  [b2735a62-0721-4d45-9410-6778bfeddb25, 8c503fc...
# 2             [446f41bd-0e52-482e-a9b7-ba462d96c5a6]
# 3  [d31b02c4-6dea-47fc-9d40-32495707fe69, e487ac1...
# 4             [18c749a3-56f4-4ea2-8628-31cafe420258]
#
#                                  id
# 0  dfdbec60270577f4607207259ab30185
# 1  eae8cf7388dd8dbd3050241c2220a0e1
# 2  5067adf50207598e357e88232eda3599
# 3  a0678cdfe9941d8478a1791feac93541
# 4  4b0b028654c036005f1af49d8be35b39

# %%
base_entity_graph_df = pd.read_parquet('./data/output/prod/artifacts/create_base_entity_graph.parquet')
base_entity_graph_df
# Out:
#    level                                    clustered_graph
# 0      0  <graphml xmlns="http://graphml.graphdrawing.or...

# %%
base_documents_df = pd.read_parquet('./data/output/prod/artifacts/create_base_documents.parquet')
base_documents_df
# Out:
#                                  id  \
# 0  0060df896c3a34f5a9489ee2405bd5a5
#
#                                           text_units  \
# 0  [eae8cf7388dd8dbd3050241c2220a0e1, 5067adf5020...
#
#                                          raw_content  \
# 0  白话版《水浒传》·武松景阳冈打虎\n武松一路走了好几天，到了阳谷县的地界。中午的时候，他觉得...
#
#                                      title
# 0  doc_1824784666541035520_shuihuzhuan.txt

# %%
summarized_entities_df = pd.read_parquet('./data/output/prod/artifacts/create_summarized_entities.parquet')
summarized_entities_df
# Out:
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...

# %%
join_text_units_to_entity_ids_df = pd.read_parquet('./data/output/prod/artifacts/join_text_units_to_entity_ids.parquet')
join_text_units_to_entity_ids_df
# Out:
#                       text_unit_ids  \
# 0  4b0b028654c036005f1af49d8be35b39
# 1  5067adf50207598e357e88232eda3599
# 2  eae8cf7388dd8dbd3050241c2220a0e1
#
#                                           entity_ids  \
# 0  [b45241d70f0e43fca764df95b2b81f77, de988724cfd...
# 1  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 2  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
#
#                                  id
# 0  4b0b028654c036005f1af49d8be35b39
# 1  5067adf50207598e357e88232eda3599
# 2  eae8cf7388dd8dbd3050241c2220a0e1

# %%
join_text_units_to_relationship_ids_df = pd.read_parquet('./data/output/prod/artifacts/join_text_units_to_relationship_ids.parquet')
join_text_units_to_relationship_ids_df
# Out:
#                                  id  \
# 0  eae8cf7388dd8dbd3050241c2220a0e1
# 1  5067adf50207598e357e88232eda3599
# 2  4b0b028654c036005f1af49d8be35b39
#
#                                     relationship_ids
# 0  [9646481f66ce4fd2b08c2eddda42fc82, d91a266f766...
# 1  [bc0e3f075a4c4ebbb7c7b152b65a5625, 254770028d7...
# 2  [e69dc259edb944ea9ea41264b9fcfe59, 3d6b216c143...

# %%
final_entities_df = pd.read_parquet('./data/output/prod/artifacts/create_final_entities.parquet')
final_entities_df
# Out:
#                                   id    name            type  \
# 0   b45241d70f0e43fca764df95b2b81f77    "武松"        "PERSON"
# 1   4119fd06010c494caa07f439b333f4c5    "老虎"           "GEO"
# 2   d3835bf3dda84ead99deadbeac5d0d7d    "酒店"  "ORGANIZATION"
# 3   077d2820ae1845bcbb1803379a3d1eae   "山神庙"           "GEO"
# 4   3671ea0dd4e84c1a9b02c5ab2c8f4bac    "告示"         "EVENT"
# 5   19a7f254a5d64566ab5cc15472df02de    "猎户"        "PERSON"
# 6   e7ffaee9d31d4d3c96e04f911d0a8f9e   "老百姓"        "PERSON"
# 7   f7e11b0e297a44a896dc67928368f600    "知县"        "PERSON"
# 8   1fd3fa8bb5a2408790042ab9573779ee   "阳谷县"           "GEO"
# 9   27f9fbe6ad8c4a8b9acee0d3596ed57c   "清河县"           "GEO"
# 10  e1fd0e904a53409aada44442f23a51cb   "武大郎"        "PERSON"
# 11  de988724cfdf45cebfba3b13c43ceede   "潘金莲"        "PERSON"
# 12  96aad7cb4b7d40e9b7e13b94a67af206  "大户人家"  "ORGANIZATION"
# 13  c9632a35146940c2a86167c7726d35e9    "东京"           "GEO"
#
#                                           description  human_readable_id  \
# 0   武松，一个高大、强壮的男子，是潘金莲的哥哥。武松的故事充满了冒险和勇气。他前往东京，在途中展...                  0
# 1   老虎是一只强壮而凶猛的动物，在故事中，它与武松的遭遇是故事中的一个转折点。老虎的出现营造了紧...                  1
# 2             "酒店是武松最初计划投宿的地方,但后来他决定继续前进,展现了他的决心和自信。"                  2
# 3          "山神庙是一个破旧的寺庙,贴有关于老虎危险的告示,为故事增添了超自然和神秘的色彩。"                  3
# 4     "告示是官方发布的关于老虎危险的通知,贴在山神庙的门上和树上,为故事增添了紧张和悬疑的气氛。"                  4
# 5                      "当地猎户感谢武松打虎,并与老百姓和知县一起向他表示感谢。"                  5
# 6                        "当地老百姓感谢武松打虎,并与猎户和知县一起向他致敬。"                  6
# 7                       "阳谷县的地方官员,他感谢武松打虎,并任命他为步兵都头。"                  7
# 8                       "武松打虎事件的发生地,也是武松被任命为步兵都头的地方。"                  8
# 9                   "武大郎和潘金莲居住的地方,也是武松最初想要回去探望哥哥的地方。"                  9
# 10                "武松的弟弟,潘金莲的丈夫,他身材矮小,相貌丑陋,受到当地人的嘲笑。"                 10
# 11  潘金莲，武松的嫂嫂，是一个美丽的女人，以她的聪慧和直率而闻名。她年轻貌美，是武大郎的妻子。潘...                 11
# 12                    "一个想要娶潘金莲做小妾但遭到拒绝的大户人家,因此怀恨在心。"                 12
# 13                        "东京是一个被提及的地理位置, 武松旅行的目的地。">                 13
#
#    graph_embedding                                      text_unit_ids
# 0             None  [4b0b028654c036005f1af49d8be35b39, 5067adf5020...
# 1             None  [5067adf50207598e357e88232eda3599, eae8cf7388d...
# 2             None                 [eae8cf7388dd8dbd3050241c2220a0e1]
# 3             None                 [eae8cf7388dd8dbd3050241c2220a0e1]
# 4             None                 [eae8cf7388dd8dbd3050241c2220a0e1]
# 5             None                 [5067adf50207598e357e88232eda3599]
# 6             None                 [5067adf50207598e357e88232eda3599]
# 7             None                 [5067adf50207598e357e88232eda3599]
# 8             None                 [5067adf50207598e357e88232eda3599]
# 9             None                 [5067adf50207598e357e88232eda3599]
# 10            None                 [5067adf50207598e357e88232eda3599]
# 11            None  [4b0b028654c036005f1af49d8be35b39, 5067adf5020...
# 12            None                 [5067adf50207598e357e88232eda3599]
# 13            None                 [4b0b028654c036005f1af49d8be35b39]

# %%
final_nodes_df = pd.read_parquet('./data/output/prod/artifacts/create_final_nodes.parquet')
final_nodes_df
# Out:
#     level   title            type  \
# 0       0    "武松"        "PERSON"
# 1       0    "老虎"           "GEO"
# 2       0    "酒店"  "ORGANIZATION"
# 3       0   "山神庙"           "GEO"
# 4       0    "告示"         "EVENT"
# 5       0    "猎户"        "PERSON"
# 6       0   "老百姓"        "PERSON"
# 7       0    "知县"        "PERSON"
# 8       0   "阳谷县"           "GEO"
# 9       0   "清河县"           "GEO"
# 10      0   "武大郎"        "PERSON"
# 11      0   "潘金莲"        "PERSON"
# 12      0  "大户人家"  "ORGANIZATION"
# 13      0    "东京"           "GEO"
#
#                                           description  \
# 0   武松，一个高大、强壮的男子，是潘金莲的哥哥。武松的故事充满了冒险和勇气。他前往东京，在途中展...
# 1   老虎是一只强壮而凶猛的动物，在故事中，它与武松的遭遇是故事中的一个转折点。老虎的出现营造了紧...
# 2             "酒店是武松最初计划投宿的地方,但后来他决定继续前进,展现了他的决心和自信。"
# 3          "山神庙是一个破旧的寺庙,贴有关于老虎危险的告示,为故事增添了超自然和神秘的色彩。"
# 4     "告示是官方发布的关于老虎危险的通知,贴在山神庙的门上和树上,为故事增添了紧张和悬疑的气氛。"
# 5                      "当地猎户感谢武松打虎,并与老百姓和知县一起向他表示感谢。"
# 6                        "当地老百姓感谢武松打虎,并与猎户和知县一起向他致敬。"
# 7                       "阳谷县的地方官员,他感谢武松打虎,并任命他为步兵都头。"
# 8                       "武松打虎事件的发生地,也是武松被任命为步兵都头的地方。"
# 9                   "武大郎和潘金莲居住的地方,也是武松最初想要回去探望哥哥的地方。"
# 10                "武松的弟弟,潘金莲的丈夫,他身材矮小,相貌丑陋,受到当地人的嘲笑。"
# 11  潘金莲，武松的嫂嫂，是一个美丽的女人，以她的聪慧和直率而闻名。她年轻貌美，是武大郎的妻子。潘...
# 12                    "一个想要娶潘金莲做小妾但遭到拒绝的大户人家,因此怀恨在心。"
# 13                        "东京是一个被提及的地理位置, 武松旅行的目的地。">
#
#                                             source_id community  degree  \
# 0   4b0b028654c036005f1af49d8be35b39,5067adf502075...         0       9
# 1   5067adf50207598e357e88232eda3599,eae8cf7388dd8...         0       2
# 2                    eae8cf7388dd8dbd3050241c2220a0e1         0       2
# 3                    eae8cf7388dd8dbd3050241c2220a0e1      None       0
# 4                    eae8cf7388dd8dbd3050241c2220a0e1         0       3
# 5                    5067adf50207598e357e88232eda3599         0       1
# 6                    5067adf50207598e357e88232eda3599         0       1
# 7                    5067adf50207598e357e88232eda3599      None       0
# 8                    5067adf50207598e357e88232eda3599         0       1
# 9                    5067adf50207598e357e88232eda3599         0       1
# 10                   5067adf50207598e357e88232eda3599         1       3
# 11  4b0b028654c036005f1af49d8be35b39,5067adf502075...         1       4
# 12                   5067adf50207598e357e88232eda3599         1       2
# 13                   4b0b028654c036005f1af49d8be35b39         1       1
#
#     human_readable_id                                id  size graph_embedding  \
# 0                   0  b45241d70f0e43fca764df95b2b81f77     9            None
# 1                   1  4119fd06010c494caa07f439b333f4c5     2            None
# 2                   2  d3835bf3dda84ead99deadbeac5d0d7d     2            None
# 3                   3  077d2820ae1845bcbb1803379a3d1eae     0            None
# 4                   4  3671ea0dd4e84c1a9b02c5ab2c8f4bac     3            None
# 5                   5  19a7f254a5d64566ab5cc15472df02de     1            None
# 6                   6  e7ffaee9d31d4d3c96e04f911d0a8f9e     1            None
# 7                   7  f7e11b0e297a44a896dc67928368f600     0            None
# 8                   8  1fd3fa8bb5a2408790042ab9573779ee     1            None
# 9                   9  27f9fbe6ad8c4a8b9acee0d3596ed57c     1            None
# 10                 10  e1fd0e904a53409aada44442f23a51cb     3            None
# 11                 11  de988724cfdf45cebfba3b13c43ceede     4            None
# 12                 12  96aad7cb4b7d40e9b7e13b94a67af206     2            None
# 13                 13  c9632a35146940c2a86167c7726d35e9     1            None
#
#                    top_level_node_id  x  y
# 0   b45241d70f0e43fca764df95b2b81f77  0  0
# 1   4119fd06010c494caa07f439b333f4c5  0  0
# 2   d3835bf3dda84ead99deadbeac5d0d7d  0  0
# 3   077d2820ae1845bcbb1803379a3d1eae  0  0
# 4   3671ea0dd4e84c1a9b02c5ab2c8f4bac  0  0
# 5   19a7f254a5d64566ab5cc15472df02de  0  0
# 6   e7ffaee9d31d4d3c96e04f911d0a8f9e  0  0
# 7   f7e11b0e297a44a896dc67928368f600  0  0
# 8   1fd3fa8bb5a2408790042ab9573779ee  0  0
# 9   27f9fbe6ad8c4a8b9acee0d3596ed57c  0  0
# 10  e1fd0e904a53409aada44442f23a51cb  0  0
# 11  de988724cfdf45cebfba3b13c43ceede  0  0
# 12  96aad7cb4b7d40e9b7e13b94a67af206  0  0
# 13  c9632a35146940c2a86167c7726d35e9  0  0

# %%
final_relationships_df = pd.read_parquet('./data/output/prod/artifacts/create_final_relationships.parquet')
final_relationships_df
# Out:
#    source  target  weight                              description  \
# 0    "武松"    "老虎"     1.0     "武松与老虎发生激烈的战斗,展现出非凡的勇气和战斗技巧,最终杀死老虎。"
# 1    "武松"   "山神庙"     1.0            "武松在山神庙门上看到了告示,意识到老虎的危险是真实的。"
# 2    "武松"    "酒店"     1.0          "武松最初计划入住酒店,但在得知老虎的危险后,决定继续前进。"
# 3    "武松"    "店家"     1.0      "武松认为店家夸大了老虎的危险以吸引顾客,因此他无视警告,独自前进。"
# 4    "武松"    "猎户"     1.0               "猎户感谢武松打虎,并与老百姓和知县一起向他致敬。"
# 5    "武松"   "老百姓"     1.0               "老百姓感谢武松打虎,并与猎户和知县一起向他致敬。"
# 6    "武松"    "知县"     1.0             "知县赏赐并任命武松为步兵都头,因为他打虎的英勇行为。"
# 7    "武松"   "武大郎"     1.0           "武松是武大郎的哥哥,他们意外相遇,武松后来住在武大郎家。"
# 8    "武松"   "潘金莲"     1.0  "潘金莲和武松是兄妹,武松试图保护她免受伤害,但她对他所给予的保护感到愤怒。"
# 9    "武松"    "东京"     1.0                            "武松暂时离开前往东京。"
# 10   "老虎"   "山神庙"     1.0               "告示贴在山神庙的门上,提醒人们老虎的存在和危险。"
# 11   "酒店"    "店家"     1.0                "店家是酒店的老板,他认为武松夸大了老虎的危险。"
# 12  "武大郎"   "潘金莲"     1.0                   "武大郎是潘金莲的丈夫,潘金莲爱上了武松。"
# 13  "武大郎"  "浮夸子弟"     1.0                "浮夸子弟嘲笑武大郎,因为他娶了年轻貌美的妻子。"
# 14  "潘金莲"  "大户人家"     1.0           "潘金莲被大户人家嫁给武大郎,因为她拒绝了大户老爷的求婚。"
# 15  "潘金莲"  "浮夸子弟"     1.0               "浮夸子弟嘲笑武大郎,因为他娶了年轻貌美的潘金莲。"
#
#                          text_unit_ids                                id  \
# 0   [eae8cf7388dd8dbd3050241c2220a0e1]  bc0e3f075a4c4ebbb7c7b152b65a5625
# 1   [eae8cf7388dd8dbd3050241c2220a0e1]  254770028d7a4fa9877da4ba0ad5ad21
# 2   [eae8cf7388dd8dbd3050241c2220a0e1]  4a67211867e5464ba45126315a122a8a
# 3   [eae8cf7388dd8dbd3050241c2220a0e1]  04dbbb2283b845baaeac0eaf0c34c9da
# 4   [5067adf50207598e357e88232eda3599]  1943f245ee4243bdbfbd2fd619ae824a
# 5   [5067adf50207598e357e88232eda3599]  273daeec8cad41e6b3e450447db58ee7
# 6   [5067adf50207598e357e88232eda3599]  e69dc259edb944ea9ea41264b9fcfe59
# 7   [5067adf50207598e357e88232eda3599]  e2f5735c7d714423a2c4f61ca2644626
# 8   [4b0b028654c036005f1af49d8be35b39]  deece7e64b2a4628850d4bb6e394a9c3
# 9   [4b0b028654c036005f1af49d8be35b39]  e657b5121ff8456b9a610cfaead8e0cb
# 10  [eae8cf7388dd8dbd3050241c2220a0e1]  bf4e255cdac94ccc83a56435a5e4b075
# 11  [eae8cf7388dd8dbd3050241c2220a0e1]  3b040bcc19f14e04880ae52881a89c1c
# 12  [5067adf50207598e357e88232eda3599]  3d6b216c14354332b1bf1927ba168986
# 13  [5067adf50207598e357e88232eda3599]  1c109cfdc370463eb6d537e5b7b382fb
# 14  [5067adf50207598e357e88232eda3599]  3d0dcbc8971b415ea18065edc4d8c8ef
# 15  [5067adf50207598e357e88232eda3599]  68105770b523412388424d984e711917
#
#    human_readable_id  source_degree  target_degree  rank
# 0                  0             10              2    12
# 1                  1             10              2    12
# 2                  2             10              2    12
# 3                  3             10              2    12
# 4                  4             10              1    11
# 5                  5             10              1    11
# 6                  6             10              1    11
# 7                  7             10              3    13
# 8                  8             10              4    14
# 9                  9             10              1    11
# 10                10              2              2     4
# 11                11              2              2     4
# 12                12              3              4     7
# 13                13              3              2     5
# 14                14              4              1     5
# 15                15              4              2     6

# %%
final_text_units_df = pd.read_parquet('./data/output/prod/artifacts/create_final_text_units.parquet')
final_text_units_df
# Out:
#                                  id  \
# 0  eae8cf7388dd8dbd3050241c2220a0e1
# 1  5067adf50207598e357e88232eda3599
# 2  4b0b028654c036005f1af49d8be35b39
# 3  dfdbec60270577f4607207259ab30185
# 4  a0678cdfe9941d8478a1791feac93541
#
#                                                 text  n_tokens  \
# 0  右三个时辰内结伴过冈。”武松笑道：“这一定是那店家用来唬人的把戏，目的就是为了让别人到他的店...      1200
# 1  �老虎的嘴一直按到那土坑里，只顾猛打。\n\n打到六七十拳的时候，老虎的眼里、口里、鼻子里、...      1200
# 2  是个老实人，我不在的时候，怕你受别人欺负。这段时间里，大哥就少做些买卖，不要和人去喝酒，早点...       198
# 3  白话版《水浒传》·武松景阳冈打虎\n武松一路走了好几天，到了阳谷县的地界。中午的时候，他觉得...      1200
# 4  莲的企图。就这么住到了十一月，一天，天上下起大雪。潘金莲一早就把武大郎赶出去卖炊饼，还买了些...      1200
#
#                          document_ids  \
# 0  [0060df896c3a34f5a9489ee2405bd5a5]
# 1  [0060df896c3a34f5a9489ee2405bd5a5]
# 2  [0060df896c3a34f5a9489ee2405bd5a5]
# 3  [0060df896c3a34f5a9489ee2405bd5a5]
# 4  [0060df896c3a34f5a9489ee2405bd5a5]
#
#                                           entity_ids  \
# 0  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 1  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 2  [b45241d70f0e43fca764df95b2b81f77, 96aad7cb4b7...
# 3                                               None
# 4                                               None
#
#                                     relationship_ids  \
# 0  [bc0e3f075a4c4ebbb7c7b152b65a5625, 254770028d7...
# 1  [1943f245ee4243bdbfbd2fd619ae824a, 273daeec8ca...
# 2  [deece7e64b2a4628850d4bb6e394a9c3, e657b5121ff...
# 3                                               None
# 4                                               None
#
#                                        covariate_ids
# 0  [b2735a62-0721-4d45-9410-6778bfeddb25, 8c503fc...
# 1             [446f41bd-0e52-482e-a9b7-ba462d96c5a6]
# 2             [18c749a3-56f4-4ea2-8628-31cafe420258]
# 3  [bf0f523c-0791-4664-abd5-3ae7e6f09428, 211bb47...
# 4  [d31b02c4-6dea-47fc-9d40-32495707fe69, e487ac1...

# %%
final_communities_df = pd.read_parquet('./data/output/prod/artifacts/create_final_communities.parquet')
final_communities_df
# Out:
#   id        title  level raw_community  \
# 0  0  Community 0      0             0
# 1  1  Community 1      0             1
# 2  2  Community 2      0             2
#
#                                     relationship_ids  \
# 0  [bc0e3f075a4c4ebbb7c7b152b65a5625, 254770028d7...
# 1  [3b040bcc19f14e04880ae52881a89c1c, 4a67211867e...
# 2  [3d6b216c14354332b1bf1927ba168986, 1c109cfdc37...
#
#                                        text_unit_ids
# 0  [4b0b028654c036005f1af49d8be35b39,5067adf50207...
# 1                 [eae8cf7388dd8dbd3050241c2220a0e1]
# 2  [5067adf50207598e357e88232eda3599, 4b0b028654c...

# %%
final_community_reports_df = pd.read_parquet('./data/output/prod/artifacts/create_final_community_reports.parquet')
final_community_reports_df
# Out:
#   community                                       full_content  level  rank  \
# 0         0  # 武松之虎传奇\n\n这个社区以武松为中心，他是一个传奇人物，在《水浒传》中与一只令人印象...      0   7.0
# 1         1  # 武松、酒店和店家\n\n这个社区以武松为中心，他无视店家关于老虎危险的警告，独自前进。店...      0   4.0
# 2         2  # 潘金莲的故事：一个复杂的女性角色\n\n这个社区围绕着潘金莲展开，她是中国文学中一个复杂...      0   6.5
#
#               title                                   rank_explanation  \
# 0            武松之虎传奇             影响严重性评级较高，这是由于武松故事的流行度和其中涉及的潜在道德与社会问题。
# 1          武松、酒店和店家                     影响严重性评级为中等，因为它涉及到个人安全和潜在的公共风险。
# 2  潘金莲的故事：一个复杂的女性角色  影响严重性评级为中等偏上。潘金莲的故事在中国文学中具有重要地位，对女性角色刻画的复杂性和非传...
#
#                                              summary  \
# 0  这个社区以武松为中心，他是一个传奇人物，在《水浒传》中与一只令人印象深刻的老虎进行了勇敢的战...
# 1  这个社区以武松为中心，他无视店家关于老虎危险的警告，独自前进。店家是酒店的老板，他认为武松夸...
# 2  这个社区围绕着潘金莲展开，她是中国文学中一个复杂而引人入胜的女性角色。潘金莲的故事涉及她的哥...
#
#                                             findings  \
# 0  [{'explanation': '武松是这个社区的核心人物，他英勇无畏，在与危险老虎的战斗...
# 1  [{'explanation': '武松无视店家关于老虎危险的警告，独自前进 [数据: 关系...
# 2  [{'explanation': '潘金莲是武大郎美丽年轻的妻子。她被描述为一个有吸引力、有...
#
#                                    full_content_json  \
# 0  {\n    "title": "武松之虎传奇",\n    "summary": "这个社...
# 1  {\n    "title": "武松、酒店和店家",\n    "summary": "这...
# 2  {\n    "title": "潘金莲的故事：一个复杂的女性角色",\n    "summ...
#
#                                      id
# 0  dd0e9dc0-710b-498d-bbce-db04bccd0d60
# 1  8bcd81ee-e1e0-4b1d-834b-313ef4b0e91b
# 2  6a5d8c29-739c-45a9-a024-22eca3554b7c

# %%
final_documents_df = pd.read_parquet('./data/output/prod/artifacts/create_final_documents.parquet')
final_documents_df
# Out:
#                                  id  \
# 0  0060df896c3a34f5a9489ee2405bd5a5
#
#                                        text_unit_ids  \
# 0  [eae8cf7388dd8dbd3050241c2220a0e1, 5067adf5020...
#
#                                          raw_content  \
# 0  白话版《水浒传》·武松景阳冈打虎\n武松一路走了好几天，到了阳谷县的地界。中午的时候，他觉得...
#
#                                      title
# 0  doc_1824784666541035520_shuihuzhuan.txt

# %%
entities = pd.read_parquet('./data/output/prod/artifacts/create_final_entities.parquet')
relationships = pd.read_parquet('./data/output/prod/artifacts/create_final_relationships.parquet')
text_units = pd.read_parquet('./data/output/prod/artifacts/create_final_text_units.parquet')
communities = pd.read_parquet('./data/output/prod/artifacts/create_final_communities.parquet')
community_reports = pd.read_parquet('./data/output/prod/artifacts/create_final_community_reports.parquet')

# %%
text_units.head(5)
# Out:
#                                  id  \
# 0  eae8cf7388dd8dbd3050241c2220a0e1
# 1  5067adf50207598e357e88232eda3599
# 2  4b0b028654c036005f1af49d8be35b39
# 3  dfdbec60270577f4607207259ab30185
# 4  a0678cdfe9941d8478a1791feac93541
#
#                                                 text  n_tokens  \
# 0  右三个时辰内结伴过冈。”武松笑道：“这一定是那店家用来唬人的把戏，目的就是为了让别人到他的店...      1200
# 1  �老虎的嘴一直按到那土坑里，只顾猛打。\n\n打到六七十拳的时候，老虎的眼里、口里、鼻子里、...      1200
# 2  是个老实人，我不在的时候，怕你受别人欺负。这段时间里，大哥就少做些买卖，不要和人去喝酒，早点...       198
# 3  白话版《水浒传》·武松景阳冈打虎\n武松一路走了好几天，到了阳谷县的地界。中午的时候，他觉得...      1200
# 4  莲的企图。就这么住到了十一月，一天，天上下起大雪。潘金莲一早就把武大郎赶出去卖炊饼，还买了些...      1200
#
#                          document_ids  \
# 0  [0060df896c3a34f5a9489ee2405bd5a5]
# 1  [0060df896c3a34f5a9489ee2405bd5a5]
# 2  [0060df896c3a34f5a9489ee2405bd5a5]
# 3  [0060df896c3a34f5a9489ee2405bd5a5]
# 4  [0060df896c3a34f5a9489ee2405bd5a5]
#
#                                           entity_ids  \
# 0  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 1  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 2  [b45241d70f0e43fca764df95b2b81f77, 96aad7cb4b7...
# 3                                               None
# 4                                               None
#
#                                     relationship_ids  \
# 0  [bc0e3f075a4c4ebbb7c7b152b65a5625, 254770028d7...
# 1  [1943f245ee4243bdbfbd2fd619ae824a, 273daeec8ca...
# 2  [deece7e64b2a4628850d4bb6e394a9c3, e657b5121ff...
# 3                                               None
# 4                                               None
#
#                                        covariate_ids
# 0  [b2735a62-0721-4d45-9410-6778bfeddb25, 8c503fc...
# 1             [446f41bd-0e52-482e-a9b7-ba462d96c5a6]
# 2             [18c749a3-56f4-4ea2-8628-31cafe420258]
# 3  [bf0f523c-0791-4664-abd5-3ae7e6f09428, 211bb47...
# 4  [d31b02c4-6dea-47fc-9d40-32495707fe69, e487ac1...

# %%
entities.head(20)
# Out:
#                                   id    name            type  \
# 0   b45241d70f0e43fca764df95b2b81f77    "武松"        "PERSON"
# 1   4119fd06010c494caa07f439b333f4c5    "老虎"           "GEO"
# 2   d3835bf3dda84ead99deadbeac5d0d7d   "山神庙"           "GEO"
# 3   077d2820ae1845bcbb1803379a3d1eae    "酒店"  "ORGANIZATION"
# 4   3671ea0dd4e84c1a9b02c5ab2c8f4bac    "店家"        "PERSON"
# 5   19a7f254a5d64566ab5cc15472df02de    "猎户"        "PERSON"
# 6   e7ffaee9d31d4d3c96e04f911d0a8f9e   "老百姓"        "PERSON"
# 7   f7e11b0e297a44a896dc67928368f600    "知县"        "PERSON"
# 8   1fd3fa8bb5a2408790042ab9573779ee  "步兵都头"          "ROLE"
# 9   27f9fbe6ad8c4a8b9acee0d3596ed57c   "清河县"           "GEO"
# 10  e1fd0e904a53409aada44442f23a51cb   "阳谷县"           "GEO"
# 11  de988724cfdf45cebfba3b13c43ceede   "武大郎"        "PERSON"
# 12  96aad7cb4b7d40e9b7e13b94a67af206   "潘金莲"        "PERSON"
# 13  c9632a35146940c2a86167c7726d35e9  "大户人家"  "ORGANIZATION"
# 14  9646481f66ce4fd2b08c2eddda42fc82  "浮夸子弟"        "PERSON"
# 15  d91a266f766b4737a06b0fda588ba40b    "东京"           "GEO"
#
#                                           description  human_readable_id  \
# 0   武松是一个高大、强壮的男人，他保护妹妹免受伤害，是一个充满爱心和保护精神的哥哥。武松的勇敢和...                  0
# 1   武松的故事中有一只令人印象深刻的老虎，它有着标志性的白色额头和强大的跳跃能力。这只危险的老虎...                  1
# 2                       "一个破败的寺庙，官府告示贴在门上，提醒人们老虎的存在。"                  2
# 3                   "武松最初计划入住的酒店，但在得知老虎的危险后，他决定继续前进。"                  3
# 4                         "酒店的老板，武松认为他夸大了老虎的危险以吸引顾客。"                  4
# 5                      "当地猎户感谢武松打虎,并与老百姓和知县一起向他表示感谢。"                  5
# 6                        "当地老百姓感谢武松打虎,并与猎户和知县一起向他致敬。"                  6
# 7                           "阳谷县的地方官,赏赐武松,并任命他为步兵都头。"                  7
# 8                                  "武松在县衙里的职位,由知县任命。"                  8
# 9                    "武大郎和潘金莲以前居住的地方,因为嘲笑而搬到了邻近的阳谷县。"                  9
# 10                "武松被任命为步兵都头并居住的地方,武大郎和潘金莲后来也搬到了这里。"                 10
# 11                         "武松的弟弟,相貌丑陋,娶了年轻貌美的潘金莲为妻。"                 11
# 12  潘金莲是武大郎美丽年轻的妻子。她精明直率，因武松的保护和哥哥的离开而备受瞩目。潘金莲爱上了武...                 12
# 13                 "一个想要娶潘金莲做小妾但遭到拒绝的大户人家,于是将她嫁给武大郎。"                 13
# 14                  "清河县一群嘲笑武大郎的年轻人,因为他娶了年轻貌美的妻子潘金莲。"                 14
# 15                        "东京是一个被提及的地理位置,是武松旅行的目的地。">                 15
#
#                                       graph_embedding  \
# 0   [-0.005042956210672855, -0.008179242722690105,...
# 1   [-0.002209516940638423, -0.004044343251734972,...
# 2   [-0.0028000809252262115, -0.0040330127812922, ...
# 3   [-0.002972010290250182, -0.003789447247982025,...
# 4   [-0.001996048493310809, -0.0037327513564378023...
# 5   [-0.0007382031762972474, -0.001683279522694647...
# 6   [-0.0017631927039474249, -0.001482860301621258...
# 7   [-0.001528459950350225, -0.0013937957119196653...
# 8                                                None
# 9                                                None
# 10                                               None
# 11  [-0.004337519872933626, -0.005476974416524172,...
# 12  [-0.003109109355136752, -0.003747215960174799,...
# 13  [-0.002652456285431981, -0.0031860140152275562...
# 14  [-0.0030061211436986923, -0.003933155443519354...
# 15  [-0.0023604638408869505, -0.001988834934309125...
#
#                                         text_unit_ids
# 0   [4b0b028654c036005f1af49d8be35b39, 5067adf5020...
# 1   [5067adf50207598e357e88232eda3599, eae8cf7388d...
# 2                  [eae8cf7388dd8dbd3050241c2220a0e1]
# 3                  [eae8cf7388dd8dbd3050241c2220a0e1]
# 4                  [eae8cf7388dd8dbd3050241c2220a0e1]
# 5                  [5067adf50207598e357e88232eda3599]
# 6                  [5067adf50207598e357e88232eda3599]
# 7                  [5067adf50207598e357e88232eda3599]
# 8                  [5067adf50207598e357e88232eda3599]
# 9                  [5067adf50207598e357e88232eda3599]
# 10                 [5067adf50207598e357e88232eda3599]
# 11                 [5067adf50207598e357e88232eda3599]
# 12  [4b0b028654c036005f1af49d8be35b39, 5067adf5020...
# 13                 [5067adf50207598e357e88232eda3599]
# 14                 [5067adf50207598e357e88232eda3599]
# 15                 [4b0b028654c036005f1af49d8be35b39]

# %%
relationships.head(5)
# Out:
#   source target  weight                           description  \
# 0   "武松"   "老虎"     1.0  "武松与老虎发生激烈的战斗,展现出非凡的勇气和战斗技巧,最终杀死老虎。"
# 1   "武松"  "山神庙"     1.0         "武松在山神庙门上看到了告示,意识到老虎的危险是真实的。"
# 2   "武松"   "酒店"     1.0       "武松最初计划入住酒店,但在得知老虎的危险后,决定继续前进。"
# 3   "武松"   "店家"     1.0   "武松认为店家夸大了老虎的危险以吸引顾客,因此他无视警告,独自前进。"
# 4   "武松"   "猎户"     1.0            "猎户感谢武松打虎,并与老百姓和知县一起向他致敬。"
#
#                         text_unit_ids                                id  \
# 0  [eae8cf7388dd8dbd3050241c2220a0e1]  bc0e3f075a4c4ebbb7c7b152b65a5625
# 1  [eae8cf7388dd8dbd3050241c2220a0e1]  254770028d7a4fa9877da4ba0ad5ad21
# 2  [eae8cf7388dd8dbd3050241c2220a0e1]  4a67211867e5464ba45126315a122a8a
# 3  [eae8cf7388dd8dbd3050241c2220a0e1]  04dbbb2283b845baaeac0eaf0c34c9da
# 4  [5067adf50207598e357e88232eda3599]  1943f245ee4243bdbfbd2fd619ae824a
#
#   human_readable_id  source_degree  target_degree  rank
# 0                 0             10              2    12
# 1                 1             10              2    12
# 2                 2             10              2    12
# 3                 3             10              2    12
# 4                 4             10              1    11

# %%
communities.head(5)
# Out:
#   id        title  level raw_community  \
# 0  0  Community 0      0             0
# 1  1  Community 1      0             1
# 2  2  Community 2      0             2
#
#                                     relationship_ids  \
# 0  [bc0e3f075a4c4ebbb7c7b152b65a5625, 254770028d7...
# 1  [3b040bcc19f14e04880ae52881a89c1c, 4a67211867e...
# 2  [3d6b216c14354332b1bf1927ba168986, 1c109cfdc37...
#
#                                        text_unit_ids
# 0  [4b0b028654c036005f1af49d8be35b39,5067adf50207...
# 1                 [eae8cf7388dd8dbd3050241c2220a0e1]
# 2  [5067adf50207598e357e88232eda3599, 4b0b028654c...

# %%
community_reports.head(5)
# Out:
#   community                                       full_content  level  rank  \
# 0         0  # 武松之虎传奇\n\n这个社区以武松为中心，他是一个传奇人物，在《水浒传》中与一只令人印象...      0   7.0
# 1         1  # 武松、酒店和店家\n\n这个社区以武松为中心，他无视店家关于老虎危险的警告，独自前进。店...      0   4.0
# 2         2  # 潘金莲的故事：一个复杂的女性角色\n\n这个社区围绕着潘金莲展开，她是中国文学中一个复杂...      0   6.5
#
#               title                                   rank_explanation  \
# 0            武松之虎传奇             影响严重性评级较高，这是由于武松故事的流行度和其中涉及的潜在道德与社会问题。
# 1          武松、酒店和店家                     影响严重性评级为中等，因为它涉及到个人安全和潜在的公共风险。
# 2  潘金莲的故事：一个复杂的女性角色  影响严重性评级为中等偏上。潘金莲的故事在中国文学中具有重要地位，对女性角色刻画的复杂性和非传...
#
#                                              summary  \
# 0  这个社区以武松为中心，他是一个传奇人物，在《水浒传》中与一只令人印象深刻的老虎进行了勇敢的战...
# 1  这个社区以武松为中心，他无视店家关于老虎危险的警告，独自前进。店家是酒店的老板，他认为武松夸...
# 2  这个社区围绕着潘金莲展开，她是中国文学中一个复杂而引人入胜的女性角色。潘金莲的故事涉及她的哥...
#
#                                             findings  \
# 0  [{'explanation': '武松是这个社区的核心人物，他英勇无畏，在与危险老虎的战斗...
# 1  [{'explanation': '武松无视店家关于老虎危险的警告，独自前进 [数据: 关系...
# 2  [{'explanation': '潘金莲是武大郎美丽年轻的妻子。她被描述为一个有吸引力、有...
#
#                                    full_content_json  \
# 0  {\n    "title": "武松之虎传奇",\n    "summary": "这个社...
# 1  {\n    "title": "武松、酒店和店家",\n    "summary": "这...
# 2  {\n    "title": "潘金莲的故事：一个复杂的女性角色",\n    "summ...
#
#                                      id
# 0  dd0e9dc0-710b-498d-bbce-db04bccd0d60
# 1  8bcd81ee-e1e0-4b1d-834b-313ef4b0e91b
# 2  6a5d8c29-739c-45a9-a024-22eca3554b7c

# %%
import pandas as pd
from neo4j import GraphDatabase
import time

# %%
NEO4J_URI = "neo4j://localhost"
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "neo4jneo4j" 
NEO4J_DATABASE = "neo4j"
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
def import_data(cypher, df, batch_size=1000):

    for i in range(0,len(df), batch_size):
        batch = df.iloc[i: min(i+batch_size, len(df))]
        result = driver.execute_query("UNWIND $rows AS value " + cypher, 
                                      rows=batch.to_dict('records'),
                                      database_=NEO4J_DATABASE)
        print(result.summary.counters)
    return

# %%
#导入text units
cypher_text_units = """
MERGE (c:__Chunk__ {id:value.id})
SET c += value {.text, .n_tokens}
WITH c, value
UNWIND value.document_ids AS document
MATCH (d:__Document__ {id:document})
MERGE (c)-[:PART_OF]->(d)
"""

import_data(cypher_text_units, text_units)
# Out:
# {'_contains_updates': True, 'properties_set': 10}

# %%
#加载entities
cypher_entities= """
MERGE (e:__Entity__ {id:value.id})
SET e += value {.human_readable_id, .description, name:replace(value.name,'"','')}
WITH e, value
CALL db.create.setNodeVectorProperty(e, "description_embedding", value.description_embedding)
CALL apoc.create.addLabels(e, case when coalesce(value.type,"") = "" then [] else [apoc.text.upperCamelCase(replace(value.type,'"',''))] end) yield node
UNWIND value.text_unit_ids AS text_unit
MATCH (c:__Chunk__ {id:text_unit})
MERGE (c)-[:HAS_ENTITY]->(e)
"""

import_data(cypher_entities, entities)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[21], line 13
#       1 #加载entities
#       2 cypher_entities= """
#       3 MERGE (e:__Entity__ {id:value.id})
#       4 SET e += value {.human_readable_id, .description, name:replace(value.name,'"','')}
#    (...)
#      10 MERGE (c)-[:HAS_ENTITY]->(e)
#      11 """
# ---> 13 import_data(cypher_entities, entities)
#
# Cell In[19], line 5, in import_data(cypher, df, batch_size)
#       3 for i in range(0,len(df), batch_size):
#       4     batch = df.iloc[i: min(i+batch_size, len(df))]
# ----> 5     result = driver.execute_query("UNWIND $rows AS value " + cypher,
#       6                                   rows=batch.to_dict('records'),
#       7                                   database_=NEO4J_DATABASE)
#       8     print(result.summary.counters)
#       9 return
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/driver.py:959, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     956     raise ValueError("Invalid routing control value: %r"
#     957                      % routing_)
#     958 with session._pipelined_begin:
# --> 959     return session._run_transaction(
#     960         access_mode, TelemetryAPI.DRIVER,
#     961         work, (query_str, parameters, result_transformer_), {}
#     962     )
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/work/session.py:554, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     552 tx = self._transaction
#     553 try:
# --> 554     result = transaction_function(tx, *args, **kwargs)
#     555 except asyncio.CancelledError:
#     556     # if cancellation callback has not been called yet:
#     557     if self._transaction is not None:
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/driver.py:1290, in _work(tx, query, parameters, transformer)
#    1284 def _work(
#    1285     tx: ManagedTransaction,
#    1286     query: te.LiteralString,
#    1287     parameters: t.Dict[str, t.Any],
#    1288     transformer: t.Callable[[Result], t.Union[_T]]
#    1289 ) -> _T:
# -> 1290     res = tx.run(query, parameters)
#    1291     return transformer(res)
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/work/transaction.py:172, in TransactionBase.run(self, query, parameters, **kwparameters)
#     169 self._results.append(result)
#     171 parameters = dict(parameters or {}, **kwparameters)
# --> 172 result._tx_ready_run(query, parameters)
#     174 return result
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/work/result.py:171, in Result._tx_ready_run(self, query, parameters)
#     167 def _tx_ready_run(self, query, parameters):
#     168     # BEGIN+RUN does not carry any extra on the RUN message.
#     169     # BEGIN {extra}
#     170     # RUN "query" {parameters} {extra}
# --> 171     self._run(query, parameters, None, None, None, None, None, None)
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/work/result.py:221, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     219 self._pull()
#     220 self._connection.send_all()
# --> 221 self._attach()
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/work/result.py:409, in Result._attach(self)
#     407 if self._exhausted is False:
#     408     while self._attached is False:
# --> 409         self._connection.fetch_message()
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     176 def inner(*args, **kwargs):
#     177     try:
# --> 178         func(*args, **kwargs)
#     179     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     180         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:855, in Bolt.fetch_message(self)
#     851 # Receive exactly one message
#     852 tag, fields = self.inbox.pop(
#     853     hydration_hooks=self.responses[0].hydration_hooks
#     854 )
# --> 855 res = self._process_message(tag, fields)
#     856 self.idle_since = monotonic()
#     857 return res
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/io/_bolt5.py:370, in Bolt5x0._process_message(self, tag, fields)
#     368 self._server_state_manager.state = self.bolt_states.FAILED
#     369 try:
# --> 370     response.on_failure(summary_metadata or {})
#     371 except (ServiceUnavailable, DatabaseUnavailable):
#     372     if self.pool:
#
# File ~/miniconda3/envs/learn-graphrag/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:245, in Response.on_failure(self, metadata)
#     243 handler = self.handlers.get("on_summary")
#     244 Util.callback(handler)
# --> 245 raise Neo4jError.hydrate(**metadata)
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureCallFailed} {message: Failed to invoke procedure `db.create.setNodeVectorProperty`: Caused by: java.lang.NullPointerException: 'vector' must not be null}

# %%
#导入relationships
cypher_relationships = """
    MATCH (source:__Entity__ {name:replace(value.source,'"','')})
    MATCH (target:__Entity__ {name:replace(value.target,'"','')})
    // not necessary to merge on id as there is only one relationship per pair
    MERGE (source)-[rel:RELATED {id: value.id}]->(target)
    SET rel += value {.rank, .weight, .human_readable_id, .description, .text_unit_ids}
    RETURN count(*) as createdRels
"""

import_data(cypher_relationships, relationships)
# Out:
# {}

# %%
#导入communities
cypher_communities = """
MERGE (c:__Community__ {community:value.id})
SET c += value {.level, .title}
/*
UNWIND value.text_unit_ids as text_unit_id
MATCH (t:__Chunk__ {id:text_unit_id})
MERGE (c)-[:HAS_CHUNK]->(t)
WITH distinct c, value
*/
WITH *
UNWIND value.relationship_ids as rel_id
MATCH (start:__Entity__)-[:RELATED {id:rel_id}]->(end:__Entity__)
MERGE (start)-[:IN_COMMUNITY]->(c)
MERGE (end)-[:IN_COMMUNITY]->(c)
RETURn count(distinct c) as createdCommunities
"""

import_data(cypher_communities, communities)
# Out:
# {'_contains_updates': True, 'labels_added': 2, 'nodes_created': 2, 'properties_set': 6}

# %%
#导入community_reports
cypher_community_reports = """MATCH (c:__Community__ {community: value.community})
SET c += value {.level, .title, .rank, .rank_explanation, .full_content, .summary}
WITH c, value
UNWIND range(0, size(value.findings)-1) AS finding_idx
WITH c, value, finding_idx, value.findings[finding_idx] as finding
MERGE (c)-[:HAS_FINDING]->(f:Finding {id: finding_idx})
SET f += finding"""
import_data(cypher_community_reports, community_reports)
# Out:
# {'_contains_updates': True, 'labels_added': 10, 'relationships_created': 10, 'nodes_created': 10, 'properties_set': 42}
